# %% [markdown]
# ## Those formulas are to solve the list of the 2° exam from Quantitative methods 1 coopead
#
# * If you have the dataset on excel use all formulas that has the argument array and use the transform_array function to transform the dataset from excel.
# * If you don't have the dataset, don't put anything in the argument of the function.

# %%
from scipy.stats import t,norm,chi2
import math
import numpy as np

# %%
#Copy a line from excel end put in the argument of function without changing,with quotes '' in the begin and in the end.
#if its a column, transpose the column on excel to a line.
def transform_array(array):
 x=array
 x=x.replace('\t',' ').replace(',','.').split(' ')
 sample=[]
 for i in x:
    if i !=' ':
        sample.append(float(i))
 return sample

# %%
#program confidence interval for proportion

def conf_inter_p(array=None):
    if array!=None:
        array=np.array(array)
        n=array.shape[0]
        alpha=float(input('What is the number of the significance(alfa should be decimal and use "." being the separator) that you want?'))
        condition=float(input('What is the benchmark to transform the array?(use "." being the separator)'))
        symbol=input('What is the condition to transform the array"<" or ">".')
        while symbol!=">" and symbol!="<":
                symbol=input('Wrong symbol,choose "<" or ">".')
        if symbol=='>':
         array=np.where(array>=condition,1,0)
        else:
         array=np.where(array<=condition,1,0)
        p_=array.sum()/n
        print('Proportion is',round(p_,4))
        LL=round(p_-norm.ppf(q=1-alpha/2)*(math.sqrt(0.25/n)),3)
        LU=round(p_+norm.ppf(q=1-alpha/2)*(math.sqrt(0.25/n)),3)
        print(LL,'<Xmean<',LU, ', with significance being:',alpha)
#Using empty argument on function
    else:
        n=int(input('What is the number of elements in the database?'))
        p_=float(input('What is the number of p/(p/ should be decimal and use "." being the separator) that you want?'))
        alpha=float(input('What is the number of the significance(alfa should be decimal and use "." being the separator) that you want?'))
        LL=round(p_-norm.ppf(q=1-alpha/2)*(math.sqrt(0.25/n)),4)
        LU=round(p_+norm.ppf(q=1-alpha/2)*(math.sqrt(0.25/n)),4)
        print(LL,'<Xmean<',LU, ', with significance being:',alpha*100,'%')

# %%
#program confidence interval for the mean of population
def conf_inter(array=None):
    if array!=None:
        array=np.array(array)
        print('The minimum value is ',array.min())
        print('The mean value is ',array.mean())
        print('The variance value is ',array.var(ddof=1))
        print('The standard deviation is ',array.std(ddof=1))
        print('The maximum is',array.max())
        n=array.shape[0]
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        if n<30:
            LL=array.mean()-t.ppf(q=1-alpha/2,df=n-1)*(array.std(ddof=1)/math.sqrt(n))
            LU=array.mean()+t.ppf(q=1-alpha/2,df=n-1)*(array.std(ddof=1)/math.sqrt(n))
        else:
            LL=array.mean()-norm.ppf(q=1-alpha/2)*(array.std(ddof=1)/math.sqrt(n))
            LU=array.mean()+norm.ppf(q=1-alpha/2)*(array.std(ddof=1)/math.sqrt(n))
        print(LL,'<Xmean<',LU)
#Using empty argument on function
    else:
        u=float(input('What is the mean of the sample in the database?'))
        n=int(input('What is the number of elements in the database?'))
        s=float(input('What is the standard deviation of the sample in the database?'))
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        if n<30:
            LL=u-t.ppf(q=1-alpha/2,df=n-1)*(s/math.sqrt(n))
            LU=u+t.ppf(q=1-alpha/2,df=n-1)*(s/math.sqrt(n))
        else:
            LL=u-norm.ppf(q=1-alpha/2)*(s/math.sqrt(n))
            LU=u+norm.ppf(q=1-alpha/2)*(s/math.sqrt(n))
        print(LL,'<Xmean<',LU)

# %%
##program confidence interval for Variance
def conf_inter_chi2(array=None):
    if array!=None:
        array=np.array(array)
        print('The minimum value is ',array.min())
        print('The mean value is ',array.mean())
        print('The variance value is ',array.var(ddof=1))
        print('The standard deviation is ',array.std(ddof=1))
        print('The maximum is',array.max())
        n=array.shape[0]
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        qui_2_UL=chi2.ppf(q=1-alpha/2,df=n-1)
        qui_2_LL=chi2.ppf(q=alpha/2,df=n-1)
        print('Upper Limit is {}'.format(qui_2_UL),'Lower Limit is {}'.format(qui_2_LL))
        print(((n-1)*array.var(ddof=1))/qui_2_UL,'<S²<',((n-1)*array.var(ddof=1))/qui_2_LL)
#Using empty argument on function
    else:
        n=int(input('What is the number of elements in the database?'))
        s_2=float(input('What is the variance of the sample in the database?'))
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        qui_2_UL=chi2.ppf(q=1-alpha/2,df=n-1)
        qui_2_LL=chi2.ppf(q=alpha/2,df=n-1)
        print('Upper Limit is {}'.format(qui_2_UL),'Lower Limit is {}'.format(qui_2_LL))
        print(((n-1)*s_2/qui_2_UL,'<S²<',((n-1)*s_2/qui_2_LL)))

# %%
# Calculate the number of samples to achieve a result using z_score
def number_samples_z():
    
    case=input('Digite if the case is proportion (s or n)')
    if case=='n':
    
        s=float(input('What is the standard deviation of the sample in the database?'))
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        ME=float(input('What is the margin of error (ME should be decimal and use "." being the separator) that you want?'))
        z=norm.ppf(q=1-alpha/2)
        n=math.ceil((z*s/ME)**2)
        print('The number of samples needed is {}'.format(n))
    else:
        
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        ME=float(input('What is the margin of error (ME should be decimal and use "." being the separator) that you want?'))
        z_2=(norm.ppf(q=1-alpha/2))**2
        n=math.ceil(z_2*0.25/(ME**2))
        print('The number of samples needed is {}'.format(n))

# %%
#Hypothesis test of the mean using z_score

def hypo_test_z(array=None):
#inputs of the problem
    if array!=None:
        array=np.array(array)
        H0=float(input('What is the null hypothesis(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        n=array.shape[0]
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        Ha_power=float(input('What is the value to analysis power?'))
        while Ha !='<>' and Ha !='<' and Ha !='>':
            Ha=input('Wrong element, please choose "<>" or "<" or ">"?')
        print('mean {}'.format(array.mean()))
        print("Standard deviation (s)",array.std(ddof=1))
        #Z-score analysis
        if Ha=='<>':
            ztest_critical=norm.ppf(q=1-alpha/2)
            ztest_Score=(array.mean()-H0)/(array.std(ddof=1)/math.sqrt(n))
            H0_critical_UL=ztest_critical*(array.std(ddof=1)/math.sqrt(n))+H0
            H0_critical_LL=H0-ztest_critical*(array.std(ddof=1)/math.sqrt(n))
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),
                  'H0_LL critical is{}'.format(H0_critical_LL),'H0_UL critical is{}'.format(H0_critical_UL))

            if ztest_Score<0 and ztest_Score<-ztest_critical :
                print('Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))   

            elif ztest_Score>0 and ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))

            else:
                if ztest_Score<0:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))
                else:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))
            #power analysis
            if Ha_power<H0:
                print('The value of Beta is{}'.format(1-norm.cdf(x=H0_critical_LL, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                print('The power is{}'.format(norm.cdf(x=H0_critical_LL, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))                                      
            else:
                print('The value of Beta is {}'.format(norm.cdf(x=H0_critical_UL, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                print('The value power is {}'.format(1-norm.cdf(x=H0_critical_UL, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n))))) 
        elif Ha=='>':
            ztest_critical=norm.ppf(q=1-alpha)
            ztest_Score=(array.mean()-H0)/(array.std(ddof=1)/math.sqrt(n))
            H0_critical=(ztest_critical*array.std(ddof=1)/math.sqrt(n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical))
            if ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
          #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The power is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))                                      
            else:
                    print('The value of Beta is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The value of Power is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))

            print('Critical value of mu ',H0_critical)        
        else:
            ztest_critical=norm.ppf(q=alpha)
            ztest_Score=(array.mean()-H0)/(array.std(ddof=1)/math.sqrt(n))
            H0_critical=ztest_critical*(array.std(ddof=1)/math.sqrt(n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical))
            if ztest_Score<-ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
            #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The power is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))                                      
            else:
                    print('The value of Beta is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The value of Power is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
            print('Critical value of mu ',H0_critical)
        
#Using empty argument on function
    else:
        n=int(input('What is the number of elements in the database?'))
        H0=float(input('What is the null hypothesis(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        Ha_power=float(input('What is the value to analysis power?'))
        while Ha !='<>' and Ha !='<' and Ha !='>':
            Ha=input('Wrong element, please choose "<>" or "<" or ">"?')
        u=float(input('What is the mean of the sample in the database?'))    
        s=float(input('What is the standard deviation of the sample in the database?'))
        if Ha=='<>':
            ztest_critical=norm.ppf(q=1-alpha/2)
            ztest_Score=(u-H0)/(s/math.sqrt(n))
            H0_critical_UL=ztest_critical*(s/math.sqrt(n))+H0
            H0_critical_LL=H0-ztest_critical*(s/math.sqrt(n))
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),
                  'H0_LL critical is{}'.format(H0_critical_LL),'H0_UL critical is{}'.format(H0_critical_UL))

            if ztest_Score<0 and ztest_Score<-ztest_critical :
                print('Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))   

            elif ztest_Score>0 and ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))

            else:
                if ztest_Score<0:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))
                else:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))
                    
            #power analysis
            if Ha_power<H0:
                print('The value of Beta is{}'.format(1-norm.cdf(x=H0_critical_LL, loc=Ha_power, scale=(s/math.sqrt(n)))))
                print('The power is{}'.format(norm.cdf(x=H0_critical_LL, loc=Ha_power, scale=(s/math.sqrt(n)))))                                      
            else:
                print('The value of Beta is {}'.format(norm.cdf(x=H0_critical_UL, loc=Ha_power, scale=(s/math.sqrt(n)))))
                print('The value power is {}'.format(1-norm.cdf(x=H0_critical_UL, loc=Ha_power, scale=(s/math.sqrt(n))))) 
        elif Ha=='>':
            ztest_critical=norm.ppf(q=1-alpha)
            ztest_Score=(u-H0)/(s/math.sqrt(n))
            H0_critical=(ztest_critical*s/math.sqrt(n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical))
            if ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
          #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=s/math.sqrt(n))))
                    print('The power is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=(s/math.sqrt(n)))))                                     
            else:
                    print('The value of Beta is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=s/math.sqrt(n))))
                    print('The value of Power is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=s/math.sqrt(n))))   
        
            print('Critical value of mu ',H0_critical)
        else:
            ztest_critical=norm.ppf(q=alpha)
            ztest_Score=(u-H0)/(s/math.sqrt(n))
            H0_critical=ztest_critical*(s/math.sqrt(n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical))
            if ztest_Score<-ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
            #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=(s/math.sqrt(n)))))
                    print('The power is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=(s/math.sqrt(n)))))                                     
            else:
                    print('The value of Beta is {}'.format(norm.cdf(x=H0_critical, loc=Ha_power, scale=s/math.sqrt(n))))
                    print('The value of Power is {}'.format(1-norm.cdf(x=H0_critical, loc=Ha_power, scale=s/math.sqrt(n))))
            print('Critical value of mu ',H0_critical)

# %%
#Hypothesis test of the mean using t_score

def hypo_test_t(array=None):
#inputs of the problem
    if array!=None:
        array=np.array(array)
        H0=float(input('What is the null hypothesis(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        n=array.shape[0]
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        Ha_power=float(input('What is the value to analysis power?'))
        while Ha !='<>' and Ha !='<' and Ha !='>':
            Ha=input('Wrong element, please choose "<>" or "<" or ">"?')
        print('mean {}'.format(array.mean()))
        print("Standard deviation (s)",array.std(ddof=1))
        #t-score analysis
        if Ha=='<>':
            ttest_critical=t.ppf(q=1-alpha/2,df=n-1)
            ttest_Score=(array.mean()-H0)/(array.std(ddof=1)/math.sqrt(n))
            H0_critical_UL=ttest_critical*(array.std(ddof=1)/math.sqrt(n))+H0
            H0_critical_LL=H0-ttest_critical*(array.std(ddof=1)/math.sqrt(n))
            print('T_score is {}'.format(ztest_Score),'critical T_score is {}'.format(ztest_critical),
                  'H0_LL critical is{}'.format(H0_critical_LL),'H0_UL critical is{}'.format(H0_critical_UL))
            
            if ttest_Score<0 and ttest_Score<-ttest_critical :
                print('Reject null hypothesis','p_value is {}'.format(2*t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))   

            elif ttest_Score>0 and ttest_Score>ttest_critical:
                print('Reject null hypothesis','p_value is {}'.format(2*(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1))))

            else:
                if ttest_Score<0:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
                else:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1))))

             #power analysis
            if Ha_power<H0:
                print('The value of Beta is{}'.format(1-t.cdf(x=H0_critical_LL, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)),df=n-1)))
                print('The power is{}'.format(t.cdf(x=H0_critical_LL, loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)),df=n-1)))                                      
            else:
                print('The value of Beta is {}'.format(t.cdf(x=H0_critical_UL, loc=Ha_power, scale=(array.std(ddof=1))/math.sqrt(n),df=n-1)))
                print('The value power is {}'.format(1-t.cdf(x=H0_critical_UL, loc=Ha_power, scale=(array.std(ddof=1))/math.sqrt(n),df=n-1))) 
            
        elif Ha=='>':
            ttest_critical=t.ppf(q=1-alpha,df=n-1)
            ttest_Score=(array.mean()-H0)/(array.std(ddof=1)/math.sqrt(n))
            H0_critical=(ttest_critical*array.std(ddof=1)/math.sqrt(n))+H0
            print('T_score is {}'.format(ttest_Score),'critical T_score is {}'.format(ttest_critical))
            if ttest_Score>ttest_critical:
                print('Reject null hypothesis','p_value is {}'.format(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
          #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The power is {}'.format(t.cdf(x=H0_critical,df=n-1,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))                                      
            else:
                    print('The value of Beta is {}'.format(t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The value of Power is {}'.format(1-t.cdf(x=H0_critical, df=n-1,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))

            print('Critical value of mu ',H0_critical)
        else:
            ttest_critical=t.ppf(q=alpha,df=n-1)
            ttest_Score=(array.mean()-H0)/(array.std(ddof=1)/math.sqrt(n))
            H0_critical=ttest_critical*(array.std(ddof=1)/math.sqrt(n))+H0
            print('T_score is {}'.format(ttest_Score),'critical T_score is {}'.format(ttest_critical))
            if ttest_Score<ttest_critical:
                print('Reject null hypothesis','p_value is {}'.format(t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
            #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The power is {}'.format(t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))                                      
            else:
                    print('The value of Beta is {}'.format(t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
                    print('The value of Power is {}'.format(1-t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))
            print('Critical value of mu ',H0_critical)
#Using empty argument on function
    else:
        H0=float(input('What is the null hypothesis(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alpha should be decimal and use "." being the separator) that you want?'))
        n=int(input('What is the number of elements in the database?'))
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        while Ha !='<>' and Ha !='<' and Ha !='>':
            Ha=input('Wrong element, please choose "<>" or "<" or ">"?')
        Ha_power=float(input('What is the value to analysis power?'))
        u=float(input('What is the mean of the sample in the database?'))    
        s=float(input('What is the standard deviation of the sample in the database?'))
        
        #t-score analysis
        if Ha=='<>':
            ttest_critical=t.ppf(q=1-alpha/2,df=n-1)
            ttest_Score=(u-H0)/(s/math.sqrt(n))
            H0_critical_UL=ttest_critical*(s/math.sqrt(n))+H0
            H0_critical_LL=H0-ttest_critical*(s/math.sqrt(n))
            print('T_score is {}'.format(ttest_Score),'critical T_score is {}'.format(ttest_critical),
                  'H0_LL critical is{}'.format(H0_critical_LL),'H0_UL critical is{}'.format(H0_critical_UL))

            if ttest_Score<0 and ttest_Score<-ttest_critical :
                print('Reject null hypothesis','p_value is {}'.format(2*t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))   

            elif ttest_Score>0 and ttest_Score>ttest_critical:
                print('Reject null hypothesis','p_value is {}'.format(2*(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1))))

            else:
                if ttest_Score<0:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
                else:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1))))
            #power analysis
            if Ha_power<H0:
                print('The value of Beta is{}'.format(1-t.cdf(x=H0_critical_LL, loc=Ha_power, scale=s/math.sqrt(n),df=n-1)))
                print('The power is{}'.format(t.cdf(x=H0_critical_LL, loc=Ha_power, scale=s/math.sqrt(n),df=n-1)))                                      
            else:
                print('The value of Beta is {}'.format(t.cdf(x=H0_critical_UL, loc=Ha_power, scale=s/math.sqrt(n),df=n-1)))
                print('The value power is {}'.format(1-t.cdf(x=H0_critical_UL, loc=Ha_power, scale=s/math.sqrt(n),df=n-1)))   
        
        elif Ha=='>':
            ttest_critical=t.ppf(q=1-alpha,df=n-1)
            ttest_Score=(u-H0)/(s/math.sqrt(n))
            H0_critical=(ttest_critical*s/math.sqrt(n))+H0
            print('T_score is {}'.format(ttest_Score),'critical T_score is {}'.format(ttest_critical))
            if ttest_Score>ttest_critical:
                print('Reject null hypothesis','p_value is {}'.format(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(1-t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
          #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(s/math.sqrt(n)))))
                    print('The power is {}'.format(t.cdf(x=H0_critical,df=n-1,loc=Ha_power, scale=(s/math.sqrt(n)))))                                      
            else:
                    print('The value of Beta is {}'.format(t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(s/math.sqrt(n)))))
                    print('The value of Power is {}'.format(1-t.cdf(x=H0_critical, df=n-1,loc=Ha_power, scale=(s/math.sqrt(n)))))
            print('Critical value of mu ',H0_critical)
        
        else:
            ttest_critical=t.ppf(q=alpha,df=n-1)
            ttest_Score=(u-H0)/(s/math.sqrt(n))
            H0_critical=ttest_critical*(s/math.sqrt(n))+H0
            print('T_score is {}'.format(ttest_Score),'critical T_score is {}'.format(ttest_critical))
            if ttest_Score<ttest_critical:
                print('Reject null hypothesis','p_value is {}'.format(t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(t.cdf(x=ttest_Score, loc=0, scale=1,df=n-1)))
            #power analysis
            if Ha_power<H0_critical:
                    print('The value of Beta is {}'.format(1-t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(s/math.sqrt(n)))))
                    print('The power is {}'.format(t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(array.std(ddof=1)/math.sqrt(n)))))                                      
            else:
                    print('The value of Beta is {}'.format(t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(s/math.sqrt(n)))))
                    print('The value of Power is {}'.format(1-t.cdf(x=H0_critical,df=n-1 ,loc=Ha_power, scale=(s/math.sqrt(n)))))
            print('Critical value of mu ',H0_critical)

# %%
#Hypothesis test of the proportion using z_score and transforming the dataset using a benchmark
def hypo_test_p_t(array):
    #transformation of the array to categorical
    array=np.array(array)
    n=array.shape[0]
    alpha=float(input('What is the number of the significance(alfa should be decimal and use "." being the separator) that you want?'))
    condition=float(input('What is the benchmark to transform the array?(use "." being the separator)'))
    symbol=input('What is the condition to transform the array"<" or ">".')
    while Ha !='<>' and Ha !='<' and Ha !='>':
        Ha=input('Wrong element, please choose "<>" or "<" or ">"?')
    while symbol!=">" and symbol!="<":
            symbol=input('Wrong symbol,choose "<" or ">".')
    if symbol=='>':
     array=np.where(array>=condition,1,0)
    else:
     array=np.where(array<=condition,1,0)
    p_=array.sum()/n
    print('Proportion is',round(p_,4))
    
    #Calculate Z-score for proportion
    H0=float(input('What is the null hypothesis(Ho should be decimal and use "." being the separator)?'))
    Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
    Ha_power=float(input('What is the value to analysis power?'))
    
    if Ha=='<>':
        ztest_critical=norm.ppf(q=1-alpha/2)
        ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
        H0_critical_UL=ztest_critical*(math.sqrt(0.25/n))+H0
        H0_critical_UL=H0-ztest_critical*(math.sqrt(0.25/n))
        print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),
                  'H0_LL critical is{}'.format(H0_critical_LL),'H0_UL critical is{}'.format(H0_critical_UL))
        
        if ztest_Score<0 and ztest_Score<-ztest_critical :
            print('Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))   
            
        elif ztest_Score>0 and ztest_Score>ztest_critical:
            print('Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))
                  
        else:
            if ztest_Score<0:
                print('Not Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))
    elif Ha=='>':
        ztest_critical=norm.ppf(q=1-alpha)
        ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
        H0_critical=ztest_critical*(math.sqrt(0.25/n))+H0
        print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),'H0 critical is{}'.format(H0_critical))
        if ztest_Score>ztest_critical:
            print('Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
        else:
            print('Not Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
    else:
        ztest_critical=norm.ppf(q=alpha)
        ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
        H0_critical=ztest_critical*(math.sqrt(0.25/n))+H0
        print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical))
        if ztest_Score<ztest_critical:
            print('Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
        else:
            print('Not Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))

# %%
#Hypothesis test of the propotion using z_score and the user giving the categorical dataset
def hypo_test_p(array=None):
    
    if array!=None:
        array=np.array(array)
        n=array.shape[0]
        p_=array.sum()/n

        #Calculate Z-score for proportion
        H0=float(input('What is the null hypothesis(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alfa should be decimal and use "." being the separator) that you want?'))
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        print('Proportion is',round(p_,4))
        if Ha=='<>':
            ztest_critical=norm.ppf(q=1-alpha/2)
            ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
            H0_critical_UL=ztest_critical*(math.sqrt(0.25/n))+H0
            H0_critical_LL=H0-ztest_critical*(math.sqrt(0.25/n))
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),
                  'H0_LL critical is{}'.format(H0_critical_LL),'H0_UL critical is{}'.format(H0_critical_UL))

            if ztest_Score<0 and ztest_Score<-ztest_critical :
                print('Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))   

            elif ztest_Score>0 and ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))

            else:
                if ztest_Score<0:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))
                else:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))
        elif Ha=='>':
            ztest_critical=norm.ppf(q=1-alpha)
            ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
            H0_critical=ztest_critical*(math.sqrt(0.25/n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),'H0 critical is{}'.format(H0_critical))
            if ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
        else:
            ztest_critical=norm.ppf(q=alpha)
            ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
            H0_critical=ztest_critical*(math.sqrt(0.25/n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical))
            if ztest_Score<ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
 #Using empty argument on function
    else:
        H0=float(input('What is the null hypothesis(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alfa should be decimal and use "." being the separator) that you want?'))
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        n=int(input('What is the number of elements in the database?'))
        p_=float(input('What is the number of p/(p/ should be decimal and use "." being the separator) that you want?'))
        
        if Ha=='<>':
            ztest_critical=norm.ppf(q=1-alpha/2)
            ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
            H0_critical_UL=ztest_critical*(math.sqrt(0.25/n))+H0
            H0_critical_LL=H0-ztest_critical*(math.sqrt(0.25/n))
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),
                  'H0_LL critical is{}'.format(H0_critical_LL),'H0_UL critical is{}'.format(H0_critical_UL))

            if ztest_Score<0 and ztest_Score<-ztest_critical :
                print('Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))   

            elif ztest_Score>0 and ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))

            else:
                if ztest_Score<0:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*norm.cdf(x=ztest_Score, loc=0, scale=1)))
                else:
                    print('Not Reject null hypothesis','p_value is {}'.format(2*(1-norm.cdf(x=ztest_Score, loc=0, scale=1))))
        
        elif Ha=='>':
            ztest_critical=norm.ppf(q=1-alpha)
            ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
            H0_critical=ztest_critical*(math.sqrt(0.25/n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical),'H0 critical is{}'.format(H0_critical))
            if ztest_Score>ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(1-norm.cdf(x=ztest_Score, loc=0, scale=1)))
        else:
            ztest_critical=norm.ppf(q=alpha)
            ztest_Score=(p_-H0)/(math.sqrt(0.25/n))
            H0_critical=ztest_critical*(math.sqrt(0.25/n))+H0
            print('Z_score is {}'.format(ztest_Score),'critical z_score is {}'.format(ztest_critical))
            if ztest_Score<ztest_critical:
                print('Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))
            else:
                print('Not Reject null hypothesis','p_value is {}'.format(norm.cdf(x=ztest_Score, loc=0, scale=1)))

# %%
#Hypothesis test of the standard deviation using chi_square, considering H0 been standard deviation
def hypo_test_chi2(array=None):
    if array!=None:
        array=np.array(array)
        n=array.shape[0]
        H0=float(input('What is the null hypothesis for standard deviation(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alfa should be decimal and use "." being the separator) that you want?'))
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        print('mean {}'.format(array.mean()))
        print("Standard deviation (s)",array.std(ddof=1))
        print("Variance (s²)",array.var(ddof=1))
        if Ha=='<>':
            chi2_critical_UL=chi2.ppf(q=1-alpha/2,df=n-1)
            chi2_critical_LL=chi2.ppf(q=alpha/2,df=n-1)
            chi_test_Score=((n-1)*array.var(ddof=1))/(H0**2)
            H0_critical_UL=math.sqrt(chi2_critical_UL*(H0**2)/(n-1))
            H0_critical_LL=math.sqrt(chi2_critical_LL*(H0**2)/(n-1))
            print('chi2_score is {}'.format(chi_test_Score),'critical Upper chi2_score is {}'.format(chi2_critical_UL),
            'critical Lower chi2_score is {}'.format(chi2_critical_LL),'"s" Upper critical is {}'.format(H0_critical_UL),
                  '"s" Lower critical is {}'.format(H0_critical_LL))

            if (chi_test_Score<chi2_critical_LL) or (chi_test_Score>chi2_critical_UL) :
                print('Reject null hypothesis')           
            else:
                print('Not Reject null hypothesis')
        elif Ha=='>':
            chi2_critical=chi2.ppf(q=1-alpha,df=n-1)
            chi_test_Score=((n-1)*array.var(ddof=1))/(H0**2)
            H0_critical=math.sqrt(chi2_critical*(H0**2)/(n-1))
            print('chi2_score is {}'.format(chi_test_Score),'critical chi2_score is {}'.format(chi2_critical),
                  '"s" critical is{}'.format(H0_critical))

            if chi_test_Score>chi2_critical :
                print('Reject null hypothesis')           
            else:
                print('Not Reject null hypothesis')

        else :

            chi2_critical=chi2.ppf(q=alpha,df=n-1)
            chi_test_Score=((n-1)*array.var(ddof=1))/(H0**2)
            H0_critical=math.sqrt(chi2_critical*(H0**2)/(n-1))
            print('chi2_score is {}'.format(chi_test_Score),'critical chi2_score is {}'.format(chi2_critical),
                  '"s" critical is{}'.format(H0_critical))

            if chi_test_Score<chi2_critical :
                print('Reject null hypothesis')           
            else:
                print('Not Reject null hypothesis')
   
 #Using empty argument on function
    else:
        H0=float(input('What is the null hypothesis for standard deviation(Ho should be decimal and use "." being the separator)?'))
        alpha=float(input('What is the number of the significance(alfa should be decimal and use "." being the separator) that you want?'))
        Ha=input('What is the alternative hypothesis(choose "<>" or "<" or ">")?')
        n=int(input('What is the number of elements in the database?'))
        s_2=float(input('What is the variance of the sample in the database?'))
        if Ha=='<>':
            chi2_critical_UL=chi2.ppf(q=1-alpha/2,df=n-1)
            chi2_critical_LL=chi2.ppf(q=alpha/2,df=n-1)
            chi_test_Score=((n-1)*s_2)/(H0**2)
            H0_critical_UL=math.sqrt(chi2_critical_UL*(H0**2)/(n-1))
            H0_critical_LL=math.sqrt(chi2_critical_LL*(H0**2)/(n-1))
            print('chi2_score is {}'.format(chi_test_Score),'critical Upper chi2_score is {}'.format(chi2_critical_UL),
            'critical Lower chi2_score is {}'.format(chi2_critical_LL),'"s" Upper critical is {}'.format(H0_critical_UL),
                  '"s" Lower critical is {}'.format(H0_critical_LL))

            if (chi_test_Score<chi2_critical_LL) or (chi_test_Score>chi2_critical_UL) :
                print('Reject null hypothesis')           
            else:
                print('Not Reject null hypothesis')
            
        elif Ha=='>':
            chi2_critical=chi2.ppf(q=1-alpha,df=n-1)
            chi_test_Score=((n-1)*s_2/(H0**2))
            H0_critical=math.sqrt(chi2_critical*(H0**2)/(n-1))
            print('chi2_score is {}'.format(chi_test_Score),'critical chi2_score is {}'.format(chi2_critical),
                  '"s" critical is{}'.format(H0_critical))

            if chi_test_Score>chi2_critical :
                print('Reject null hypothesis')           
            else:
                print('Not Reject null hypothesis')
          
        else :

            chi2_critical=chi2.ppf(q=alpha,df=n-1)
            chi_test_Score=((n-1)*s_2/(H0**2))
            H0_critical=math.sqrt(chi2_critical*(H0**2)/(n-1))
            print('chi2_score is {}'.format(chi_test_Score),'critical chi2_score is {}'.format(chi2_critical),
                  '"s" critical is{}'.format(H0_critical))

            if chi_test_Score<chi2_critical :
                print('Reject null hypothesis')           
            else:
                print('Not Reject null hypothesis')

# %% [markdown]
# # Sumary of the formulas to use in quantitative methods 1
# ## For all formulas using an argument array, you have to transform the dataset doing that:
# 1. Copy the line from excel to python, if its a column in excel transpose that to a line.
# 1. Create a variable that you are going to atribute the dataset in python
# 1. Atribute the valor of the variable using the function transform_array(array), in "array" substitute the line from excel
# 1. Put ' at the begin and the end of the argument of the function transform_array, like transform_array('ctrl+v from the entire line on excel')
# 1. The code is like variable=transform_array('ctrl+v from the entire line on excel')
# 1. Use that "variable" as an argument for all functions that you want
# ### All proportion codes were developed using the conservative variance var=0.25
#
# ### Functions
# 1. transform_array(array)
# * Copy a line from excel end put in the argument of function without changing,with quotes '' in the begin and in the end.
# * if its a column, transpose the column on excel to a line.
#
# 2. conf_inter_p() or conf_inter_p(array)
# * confidence interval for proportion
#
# 3. conf_inter() or conf_inter(array)
# * confidence interval for the mean of population
#
# 4. number_samples_z()
# * Calculate the number of samples to achieve a margin of error using z_score for proportion or continuous
#
# 5. number_samples_t()
# * Calculate the number of samples to achieve a margin of error using t_score
#
# 6. conf_inter_chi2() or conf_inter_chi2(array)
# * confidence interval for Variance
#
# 7. hypo_test_z() or hypo_test_z(array)
# * Hypothesis test of the mean using z_score
#
# 8. hypo_test_t() or hypo_test_t(array)
# * Hypothesis test of the mean using t_score
#
# 9. hypo_test_p_t(array)
# * Hypothesis test of the proportion using z_score and transforming the dataset using a benchmark
#
# 10. hypo_test_p() or hypo_test_p(array)
# * Hypothesis test of the proportion using z_score and the user giving the categorical dataset or not
#
# 11. hypo_test_chi2() or hypo_test_chi2(array)
# *  Hypothesis test of the standard deviation using chi_square
